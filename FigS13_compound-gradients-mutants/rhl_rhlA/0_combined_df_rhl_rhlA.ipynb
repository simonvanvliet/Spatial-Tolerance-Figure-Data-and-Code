# %%
# Import required libraries
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# # Aggregate Fluorescence Intensity Data for rhl reporter in presence of rhlA mutant
# ## Overview
# This notebook aggregates fluorescence intensity data from multiple experimental replicates and positions for the rhlA strain.
#
# ## Workflow
# 1. **Input Processing**: Iterates through all `replicate*` folders in the input directory
# 2. **Data Collection**: For each replicate, searches for `pos*` folders and loads the `phase/fluo_intensities.csv` file when present
# 3. **Metadata Addition**: Adds the following metadata columns to each dataframe:
#    - `strain`: Set to `'rhlA'`
#    - `replicate`: Replicate identifier
#    - `pos`: Position identifier
# 4. **Data Combination**: Concatenates all individual dataframes into a single unified dataset
# 5. **Output**: Saves the combined dataframe as `0_combined_df_rhl_rhlA.csv`

# %%
# Define input and output paths
input_dir = '../../../Image_Data/Review/rhl_rhlA'
output_dir = './0_combined_df_rhl_rhlA.csv'

if not os.path.isdir(input_dir):
    raise FileNotFoundError(
        f"Could not find input directory: {input_dir}. Current working dir: {os.getcwd()}"
    )

# Initialize list to store individual dataframes
all_data = []

# Iterate through replicate folders
for replicate_folder in os.listdir(input_dir):
    replicate_path = os.path.join(input_dir, replicate_folder)

    # Process only replicate directories
    if os.path.isdir(replicate_path) and replicate_folder.startswith('replicate'):

        # Iterate through position folders within each replicate
        for pos_folder in os.listdir(replicate_path):
            if pos_folder.startswith('pos'):
                pos_path = os.path.join(replicate_path, pos_folder, 'phase', 'fluo_intensities.csv')

                # Load data if CSV file exists
                if os.path.isfile(pos_path):
                    df = pd.read_csv(pos_path)

                    # Add metadata columns
                    df.insert(1, 'strain', 'rhlA')
                    df.insert(2, 'replicate', replicate_folder)
                    df.insert(3, 'pos', pos_folder)

                    # Append to collection
                    all_data.append(df)

# Combine all dataframes and save to output file
if all_data:
    combined_df_rhl_rhlA = pd.concat(all_data, ignore_index=True)
    combined_df_rhl_rhlA.to_csv(output_dir, index=False)
    print(f"Successfully combined {len(all_data)} datasets")
    print(f"Total rows: {len(combined_df_rhl_rhlA)}")
    print(f"Output saved to: {output_dir}")

    # Display first few rows
    combined_df_rhl_rhlA.head()
else:
    print("Warning: No data files found")
# Out:
# Successfully combined 20 datasets
# Total rows: 66305
# Output saved to: ./0_combined_df_rhl_rhlA.csv

# %%
combined_df_rhl_rhlA
# Out:
#        label strain    replicate   pos   area  min_row  min_col  max_row  \
# 0          1   rhlA  replicate_2  pos9   82.0        1       22       11
# 1          2   rhlA  replicate_2  pos9  114.0        1      183       13
# 2          3   rhlA  replicate_2  pos9   76.0        1      267       11
# 3          4   rhlA  replicate_2  pos9  103.0        1      348       12
# 4          5   rhlA  replicate_2  pos9   78.0        1      545       11
# ...      ...    ...          ...   ...    ...      ...      ...      ...
# 66300   3363   rhlA  replicate_1  pos8   83.0      708      678      718
# 66301   3364   rhlA  replicate_1  pos8   44.0      709      326      716
# 66302   3365   rhlA  replicate_1  pos8   36.0      709      360      716
# 66303   3366   rhlA  replicate_1  pos8   57.0      709      408      718
# 66304   3367   rhlA  replicate_1  pos8   76.0      709      510      718
#
#        max_col  intensity_max  intensity_mean  intensity_min  \
# 0           32         1369.0     1091.292683          807.0
# 1          194         1335.0     1092.692982          755.0
# 2          276         1445.0     1220.302632          906.0
# 3          359         1682.0     1355.893204          889.0
# 4          554         1640.0     1223.833333          879.0
# ...        ...            ...             ...            ...
# 66300      688         2237.0     1819.698795         1350.0
# 66301      334         1204.0     1048.954545          908.0
# 66302      367         1096.0      958.833333          801.0
# 66303      416         1509.0     1247.789474         1015.0
# 66304      520         1859.0     1552.750000         1213.0
#
#        minor_axis_length  major_axis_length           y           x  \
# 0               9.838313          10.629109    5.195122   26.439024
# 1              11.959592          12.255432    6.307018  187.991228
# 2               9.618695          10.089287    5.276316  271.052632
# 3              11.434086          11.535244    5.825243  353.126214
# 4               9.529957          10.440359    5.397436  549.141026
# ...                  ...                ...         ...         ...
# 66300          10.175295          10.385627  712.337349  682.409639
# 66301           7.160027           7.872337  712.250000  329.704545
# 66302           6.616478           7.023769  712.416667  363.083333
# 66303           8.357691           8.683025  713.298246  411.385965
# 66304           9.490044          10.167026  713.052632  514.500000
#
#        intensity_mcherry  intensity_raw_mcherry  frame_number
# 0              33.256098            1091.292683             0
# 1              33.298246            1092.692982             0
# 2              38.434211            1220.302632             0
# 3              43.864078            1355.893204             0
# 4              38.615385            1223.833333             0
# ...                  ...                    ...           ...
# 66300          37.951807            1819.698795             0
# 66301          19.068182            1048.954545             0
# 66302          16.833333             958.833333             0
# 66303          24.000000            1247.789474             0
# 66304          31.394737            1552.750000             0
#
# [66305 rows x 19 columns]
