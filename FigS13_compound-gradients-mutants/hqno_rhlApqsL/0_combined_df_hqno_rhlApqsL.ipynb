# %%
# Import required libraries
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# # Aggregate Fluorescence Intensity Data for hqno reporter in presence of rhlA pqsL mutant
# ## Overview
# This notebook aggregates fluorescence intensity data from multiple experimental replicates and positions for the rhlA pqsL strain.
#
# ## Workflow
# 1. **Input Processing**: Iterates through all `replicate*` folders in the input directory
# 2. **Data Collection**: For each replicate, searches for `pos*` folders and loads the `phase/fluo_intensities.csv` file when present
# 3. **Metadata Addition**: Adds the following metadata columns to each dataframe:
#    - `strain`: Set to `'rhlApqsL'`
#    - `replicate`: Replicate identifier
#    - `pos`: Position identifier
# 4. **Data Combination**: Concatenates all individual dataframes into a single unified dataset
# 5. **Output**: Saves the combined dataframe as `0_combined_df_hqno_rhlApqsL.csv`

# %%
# Define input and output paths
input_dir = '../../../Image_Data/Review/hqno_rhlApqsL'
output_dir = './0_combined_df_hqno_rhlApqsL.csv'

if not os.path.isdir(input_dir):
    raise FileNotFoundError(
        f"Could not find input directory: {input_dir}. Current working dir: {os.getcwd()}"
    )

# Initialize list to store individual dataframes
all_data = []

# Iterate through replicate folders
for replicate_folder in os.listdir(input_dir):
    replicate_path = os.path.join(input_dir, replicate_folder)

    # Process only replicate directories
    if os.path.isdir(replicate_path) and replicate_folder.startswith('replicate'):

        # Iterate through position folders within each replicate
        for pos_folder in os.listdir(replicate_path):
            if pos_folder.startswith('pos'):
                pos_path = os.path.join(replicate_path, pos_folder, 'phase', 'fluo_intensities.csv')

                # Load data if CSV file exists
                if os.path.isfile(pos_path):
                    df = pd.read_csv(pos_path)

                    # Add metadata columns
                    df.insert(1, 'strain', 'rhlApqsL')
                    df.insert(2, 'replicate', replicate_folder)
                    df.insert(3, 'pos', pos_folder)

                    # Append to collection
                    all_data.append(df)

# Combine all dataframes and save to output file
if all_data:
    combined_df_hqno_rhlApqsL = pd.concat(all_data, ignore_index=True)
    combined_df_hqno_rhlApqsL.to_csv(output_dir, index=False)
    print(f"Successfully combined {len(all_data)} datasets")
    print(f"Total rows: {len(combined_df_hqno_rhlApqsL)}")
    print(f"Output saved to: {output_dir}")

    # Display first few rows
    combined_df_hqno_rhlApqsL.head()
else:
    print("Warning: No data files found")
# Out:
# Successfully combined 20 datasets
# Total rows: 62975
# Output saved to: ./0_combined_df_hqno_rhlApqsL.csv

# %%
combined_df_hqno_rhlApqsL
# Out:
#        label    strain    replicate   pos   area  min_row  min_col  max_row  \
# 0          1  rhlApqsL  replicate_2  pos9   75.0        1      298       10
# 1          2  rhlApqsL  replicate_2  pos9   86.0        2       97       12
# 2          3  rhlApqsL  replicate_2  pos9  105.0        2      217       13
# 3          4  rhlApqsL  replicate_2  pos9   96.0        2      413       13
# 4          5  rhlApqsL  replicate_2  pos9  100.0        2      451       13
# ...      ...       ...          ...   ...    ...      ...      ...      ...
# 62970   3189  rhlApqsL  replicate_1  pos8   34.0      649      410      656
# 62971   3190  rhlApqsL  replicate_1  pos8   49.0      649      573      657
# 62972   3191  rhlApqsL  replicate_1  pos8   47.0      649      607      657
# 62973   3192  rhlApqsL  replicate_1  pos8   44.0      650      124      657
# 62974   3193  rhlApqsL  replicate_1  pos8   31.0      650      388      656
#
#        max_col  intensity_max  intensity_mean  intensity_min  \
# 0          308          281.0      223.973333          176.0
# 1          107          284.0      226.790698          159.0
# 2          228          279.0      223.771429          159.0
# 3          424          284.0      217.572917          152.0
# 4          462          273.0      217.850000          167.0
# ...        ...            ...             ...            ...
# 62970      417          298.0      258.176471          210.0
# 62971      581          321.0      256.122449          193.0
# 62972      615          325.0      255.893617          218.0
# 62973      131          340.0      258.340909          198.0
# 62974      394          324.0      265.290323          221.0
#
#        minor_axis_length  major_axis_length           y           x  \
# 0               9.491719          10.035850    5.026667  302.440000
# 1              10.301772          10.666996    6.662791  101.779070
# 2              11.435404          11.708592    6.971429  222.171429
# 3              10.852825          11.354112    6.635417  417.645833
# 4              11.212728          11.401945    7.100000  456.130000
# ...                  ...                ...         ...         ...
# 62970           6.339182           6.888753  652.235294  413.235294
# 62971           7.633316           8.177225  652.163265  576.224490
# 62972           7.621517           7.972925  652.744681  610.765957
# 62973           7.303910           7.627701  653.045455  126.931818
# 62974           5.950315           6.733719  652.096774  390.483871
#
#        intensity_gfp  intensity_raw_gfp  frame_number
# 0           7.573333         223.973333             0
# 1           7.744186         226.790698             0
# 2           7.571429         223.771429             0
# 3           7.072917         217.572917             0
# 4           7.150000         217.850000             0
# ...              ...                ...           ...
# 62970      22.558824         258.176471             0
# 62971      22.183673         256.122449             0
# 62972      22.148936         255.893617             0
# 62973      22.636364         258.340909             0
# 62974      23.774194         265.290323             0
#
# [62975 rows x 19 columns]
