# %%
# Import required libraries
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# # Aggregate Fluorescence Intensity Data for rhl reporter in presence of rhlA pqsL mutant
# ## Overview
# This notebook aggregates fluorescence intensity data from multiple experimental replicates and positions for the rhlA pqsL strain.
#
# ## Workflow
# 1. **Input Processing**: Iterates through all `replicate*` folders in the input directory
# 2. **Data Collection**: For each replicate, searches for `pos*` folders and loads the `phase/fluo_intensities.csv` file when present
# 3. **Metadata Addition**: Adds the following metadata columns to each dataframe:
#    - `strain`: Set to `'rhlApqsL'`
#    - `replicate`: Replicate identifier
#    - `pos`: Position identifier
# 4. **Data Combination**: Concatenates all individual dataframes into a single unified dataset
# 5. **Output**: Saves the combined dataframe as `0_combined_df_rhl_rhlApqsL.csv`

# %%
# Define input and output paths
input_dir = '../../../Image_Data/Review/rhl_rhlApqsL'
output_dir = './0_combined_df_rhl_rhlApqsL.csv'

if not os.path.isdir(input_dir):
    raise FileNotFoundError(
        f"Could not find input directory: {input_dir}. Current working dir: {os.getcwd()}"
    )

# Initialize list to store individual dataframes
all_data = []

# Iterate through replicate folders
for replicate_folder in os.listdir(input_dir):
    replicate_path = os.path.join(input_dir, replicate_folder)

    # Process only replicate directories
    if os.path.isdir(replicate_path) and replicate_folder.startswith('replicate'):

        # Iterate through position folders within each replicate
        for pos_folder in os.listdir(replicate_path):
            if pos_folder.startswith('pos'):
                pos_path = os.path.join(replicate_path, pos_folder, 'phase', 'fluo_intensities.csv')

                # Load data if CSV file exists
                if os.path.isfile(pos_path):
                    df = pd.read_csv(pos_path)

                    # Add metadata columns
                    df.insert(1, 'strain', 'rhlApqsL')
                    df.insert(2, 'replicate', replicate_folder)
                    df.insert(3, 'pos', pos_folder)

                    # Append to collection
                    all_data.append(df)

# Combine all dataframes and save to output file
if all_data:
    combined_df_rhl_rhlApqsL = pd.concat(all_data, ignore_index=True)
    combined_df_rhl_rhlApqsL.to_csv(output_dir, index=False)
    print(f"Successfully combined {len(all_data)} datasets")
    print(f"Total rows: {len(combined_df_rhl_rhlApqsL)}")
    print(f"Output saved to: {output_dir}")

    # Display first few rows
    combined_df_rhl_rhlApqsL.head()
else:
    print("Warning: No data files found")
# Out:
# Successfully combined 24 datasets
# Total rows: 85440
# Output saved to: ./0_combined_df_rhl_rhlApqsL.csv

# %%
combined_df_rhl_rhlApqsL
# Out:
#        label    strain    replicate   pos   area  min_row  min_col  max_row  \
# 0          1  rhlApqsL  replicate_2  pos9   47.0        1       68        8
# 1          2  rhlApqsL  replicate_2  pos9   67.0        1      108       10
# 2          3  rhlApqsL  replicate_2  pos9  114.0        1      384       13
# 3          4  rhlApqsL  replicate_2  pos9   48.0        2      189        9
# 4          5  rhlApqsL  replicate_2  pos9   62.0        2      224       11
# ...      ...       ...          ...   ...    ...      ...      ...      ...
# 85435   3449  rhlApqsL  replicate_1  pos8   60.0      730      469      738
# 85436   3450  rhlApqsL  replicate_1  pos8   52.0      730      536      737
# 85437   3451  rhlApqsL  replicate_1  pos8   42.0      730      636      737
# 85438   3452  rhlApqsL  replicate_1  pos8   25.0      732      155      737
# 85439   3453  rhlApqsL  replicate_1  pos8   26.0      733      210      738
#
#        max_col  intensity_max  intensity_mean  intensity_min  \
# 0           76         1373.0     1103.957447          821.0
# 1          117         1145.0      939.208955          708.0
# 2          395         1823.0     1414.192982          844.0
# 3          197         1151.0      987.812500          790.0
# 4          233         1359.0     1129.080645          843.0
# ...        ...            ...             ...            ...
# 85435      478         1623.0     1360.366667         1115.0
# 85436      544         1426.0     1218.903846         1029.0
# 85437      644         1333.0     1210.476190         1025.0
# 85438      161         1146.0     1018.520000          891.0
# 85439      216         1285.0     1149.692308         1013.0
#
#        minor_axis_length  major_axis_length           y           x  \
# 0               7.493726           7.995912    4.063830   71.851064
# 1               9.176264           9.358400    4.791045  112.104478
# 2              11.832312          12.333124    6.324561  389.078947
# 3               7.494600           8.180965    4.937500  192.770833
# 4               8.842712           8.961474    6.419355  227.580645
# ...                  ...                ...         ...         ...
# 85435           8.578881           8.964283  733.600000  473.133333
# 85436           7.605666           8.682431  733.000000  539.500000
# 85437           7.144667           7.495515  732.976190  639.500000
# 85438           5.301741           5.982403  734.080000  157.800000
# 85439           5.203549           6.201737  735.000000  212.500000
#
#        intensity_mcherry  intensity_raw_mcherry  frame_number
# 0              37.191489            1103.957447             0
# 1              30.328358             939.208955             0
# 2              49.877193            1414.192982             0
# 3              32.291667             987.812500             0
# 4              38.177419            1129.080645             0
# ...                  ...                    ...           ...
# 85435          46.183333            1360.366667             0
# 85436          39.807692            1218.903846             0
# 85437          39.452381            1210.476190             0
# 85438          30.720000            1018.520000             0
# 85439          36.615385            1149.692308             0
#
# [85440 rows x 19 columns]
